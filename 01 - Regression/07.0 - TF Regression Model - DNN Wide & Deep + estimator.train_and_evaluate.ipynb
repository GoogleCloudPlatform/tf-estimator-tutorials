# %%
import tensorflow as tf
import numpy as np
from tensorflow import data
import shutil
import math
from datetime import datetime
from tensorflow.python.feature_column import feature_column

print(tf.__version__)
# Out:
# 1.4.0

# %% [markdown]
# ## Steps to use the TF Estimator (Train_And_Evaluate) APIs
# 1. Define dataset **metadata**
# 2. Define **data input function** to read the data from .tfrecord files + **feature processing**
# 3. Create TF **feature columns** based on metadata + **extended feature columns**
# 4. Define an **estimator** (LinearCombinedDNNRegressor) with the required **feature columns (wide/deep) & parameters**
# 7. Run an experiment using the estimator **train_and_evaluate** function to train, evaluate, and export the model
# 8. **Evaluate** the model using test data
# 9. Perform **predictions** & **serving** the exported model

# %%
MODEL_NAME = 'reg-model-06'

TRAIN_DATA_FILES_PATTERN = 'data/train-*.tfrecords'
VALID_DATA_FILES_PATTERN = 'data/valid-*.tfrecords'
TEST_DATA_FILES_PATTERN = 'data/test-*.tfrecords'

RESUME_TRAINING = False
PROCESS_FEATURES = True
EXTEND_FEATURE_COLUMNS = True
MULTI_THREADING = True

# %% [markdown]
# ## 1. Define Dataset Metadata
# * tf.example feature names and defaults
# * Numeric and categorical feature names
# * Target feature name
# * Unused features

# %%
HEADER = ['key','x','y','alpha','beta','target']
HEADER_DEFAULTS = [[0], [0.0], [0.0], ['NA'], ['NA'], [0.0]]

NUMERIC_FEATURE_NAMES = ['x', 'y']  

CATEGORICAL_FEATURE_NAMES_WITH_VOCABULARY = {'alpha':['ax01', 'ax02'], 'beta':['bx01', 'bx02']}
CATEGORICAL_FEATURE_NAMES = list(CATEGORICAL_FEATURE_NAMES_WITH_VOCABULARY.keys())

FEATURE_NAMES = NUMERIC_FEATURE_NAMES + CATEGORICAL_FEATURE_NAMES

TARGET_NAME = 'target'

UNUSED_FEATURE_NAMES = list(set(HEADER) - set(FEATURE_NAMES) - {TARGET_NAME})

print("Header: {}".format(HEADER))
print("Numeric Features: {}".format(NUMERIC_FEATURE_NAMES))
print("Categorical Features: {}".format(CATEGORICAL_FEATURE_NAMES))
print("Target: {}".format(TARGET_NAME))
print("Unused Features: {}".format(UNUSED_FEATURE_NAMES))
# Out:
# Header: ['key', 'x', 'y', 'alpha', 'beta', 'target']
# Numeric Features: ['x', 'y']
# Categorical Features: ['alpha', 'beta']
# Target: target
# Unused Features: ['key']

# %% [markdown]
# ## 2. Define Data Input Function
# * Input .tfrecords files name pattern
# * Use TF Dataset APIs to read and process the data
# * Parse tf.exmaples  to feature tensors
# * Apply feature processing
# * Return (features, target) tensors

# %% [markdown]
# ### a. parsing and preprocessing logic

# %%
def parse_tf_example(example_proto):

    feature_spec = {}

    for feature_name in NUMERIC_FEATURE_NAMES:
        feature_spec[feature_name] = tf.FixedLenFeature(shape=(1), dtype=tf.float32)
    
    for feature_name in CATEGORICAL_FEATURE_NAMES:
        feature_spec[feature_name] = tf.FixedLenFeature(shape=(1), dtype=tf.string)
    
    feature_spec[TARGET_NAME] = tf.FixedLenFeature(shape=(1), dtype=tf.float32)

    parsed_features = tf.parse_example(serialized=example_proto, features=feature_spec)
    
    target = parsed_features.pop(TARGET_NAME)
    
    return parsed_features, target


def process_features(features):
    
    # example of clipping
    features['x'] = tf.clip_by_value(features['x'], clip_value_min=-3, clip_value_max=3)
    features['y'] = tf.clip_by_value(features['y'], clip_value_min=-3, clip_value_max=3)
    
    # example of polynomial expansion
    features["x_2"] = tf.square(features['x'])
    features["y_2"] = tf.square(features['y'])
    
    # example of nonlinearity
    features["xy"] = features['x'] * features['y']
    
    # example of custom logic
    features['dist_xy'] =  tf.sqrt(tf.squared_difference(features['x'],features['y']))
    features["sin_x"] = tf.sin(features['x'])
    features["cos_y"] = tf.sin(features['y'])
    
    
    
    return features

# %% [markdown]
# ### b. data pipeline input function

# %%
def tfrecods_input_fn(files_name_pattern, mode=tf.estimator.ModeKeys.EVAL, 
                 num_epochs=None, 
                 batch_size=200):
    
    shuffle = True if mode == tf.estimator.ModeKeys.TRAIN else False
    
    print("")
    print("* data input_fn:")
    print("================")
    print("Input file(s): {}".format(files_name_pattern))
    print("Batch size: {}".format(batch_size))
    print("Epoch Count: {}".format(num_epochs))
    print("Mode: {}".format(mode))
    print("Shuffle: {}".format(shuffle))
    print("================")
    print("")

    file_names = tf.matching_files(files_name_pattern)
    dataset = data.TFRecordDataset(filenames=file_names)

    if shuffle:
        dataset = dataset.shuffle(buffer_size=2 * batch_size + 1)
    
    dataset = dataset.batch(batch_size)
    dataset = dataset.map(lambda tf_example: parse_tf_example(tf_example))
    
    if PROCESS_FEATURES:
        dataset = dataset.map(lambda features, target: (process_features(features), target))
        
    dataset = dataset.repeat(num_epochs)
    iterator = dataset.make_one_shot_iterator()
    
    features, target = iterator.get_next()
    return features, target

# %%
features, target = tfrecods_input_fn(files_name_pattern="")
print("Feature read from TFRecords: {}".format(list(features.keys())))
print("Target read from TFRecords: {}".format(target))
# Out:
# * data input_fn:
# ================
# Input file(s):
# Batch size: 200
# Epoch Count: None
# Mode: eval
# Shuffle: False
# ================
#
# Feature read from TFRecords: ['alpha', 'beta', 'x', 'y', 'x_2', 'y_2', 'xy', 'dist_xy', 'sin_x', 'cos_y']
# Target read from TFRecords: Tensor("IteratorGetNext:10", shape=(?, 1), dtype=float32)

# %% [markdown]
# ## 3. Define Feature Columns
# The input numeric columns are assumed to be normalized (or have the same scale). Otherise, a normlizer_fn, along with the normlisation params (mean, stdv) should be passed to tf.feature_column.numeric_column() constructor

# %%
def extend_feature_columns(feature_columns, hparams):
    
    num_buckets = hparams.num_buckets
    embedding_size = hparams.embedding_size

    buckets = np.linspace(-3, 3, num_buckets).tolist()

    alpha_X_beta = tf.feature_column.crossed_column(
            [feature_columns['alpha'], feature_columns['beta']], 4)

    x_bucketized = tf.feature_column.bucketized_column(
            feature_columns['x'], boundaries=buckets)

    y_bucketized = tf.feature_column.bucketized_column(
            feature_columns['y'], boundaries=buckets)

    x_bucketized_X_y_bucketized = tf.feature_column.crossed_column(
           [x_bucketized, y_bucketized], num_buckets**2)

    x_bucketized_X_y_bucketized_embedded = tf.feature_column.embedding_column(
            x_bucketized_X_y_bucketized, dimension=embedding_size)


    feature_columns['alpha_X_beta'] = alpha_X_beta
    feature_columns['x_bucketized_X_y_bucketized'] = x_bucketized_X_y_bucketized
    feature_columns['x_bucketized_X_y_bucketized_embedded'] = x_bucketized_X_y_bucketized_embedded
    
    return feature_columns
    

def get_feature_columns(hparams):
    
    CONSTRUCTED_NUMERIC_FEATURES_NAMES = ['x_2', 'y_2', 'xy', 'dist_xy', 'sin_x', 'cos_y']
    all_numeric_feature_names = NUMERIC_FEATURE_NAMES.copy() 
    
    if PROCESS_FEATURES:
        all_numeric_feature_names += CONSTRUCTED_NUMERIC_FEATURES_NAMES

    numeric_columns = {feature_name: tf.feature_column.numeric_column(feature_name)
                       for feature_name in all_numeric_feature_names}

    categorical_column_with_vocabulary = \
        {item[0]: tf.feature_column.categorical_column_with_vocabulary_list(item[0], item[1])
         for item in CATEGORICAL_FEATURE_NAMES_WITH_VOCABULARY.items()}
        
    feature_columns = {}

    if numeric_columns is not None:
        feature_columns.update(numeric_columns)

    if categorical_column_with_vocabulary is not None:
        feature_columns.update(categorical_column_with_vocabulary)
    
    if EXTEND_FEATURE_COLUMNS:
        feature_columns = extend_feature_columns(feature_columns, hparams)
        
    return feature_columns

feature_columns = get_feature_columns(tf.contrib.training.HParams(num_buckets=5,embedding_size=3))
print("Feature Columns: {}".format(feature_columns))
# Out:
# Feature Columns: {'x': _NumericColumn(key='x', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None), 'y': _NumericColumn(key='y', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None), 'x_2': _NumericColumn(key='x_2', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None), 'y_2': _NumericColumn(key='y_2', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None), 'xy': _NumericColumn(key='xy', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None), 'dist_xy': _NumericColumn(key='dist_xy', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None), 'sin_x': _NumericColumn(key='sin_x', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None), 'cos_y': _NumericColumn(key='cos_y', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None), 'alpha': _VocabularyListCategoricalColumn(key='alpha', vocabulary_list=('ax01', 'ax02'), dtype=tf.string, default_value=-1, num_oov_buckets=0), 'beta': _VocabularyListCategoricalColumn(key='beta', vocabulary_list=('bx01', 'bx02'), dtype=tf.string, default_value=-1, num_oov_buckets=0), 'alpha_X_beta': _CrossedColumn(keys=(_VocabularyListCategoricalColumn(key='alpha', vocabulary_list=('ax01', 'ax02'), dtype=tf.string, default_value=-1, num_oov_buckets=0), _VocabularyListCategoricalColumn(key='beta', vocabulary_list=('bx01', 'bx02'), dtype=tf.string, default_value=-1, num_oov_buckets=0)), hash_bucket_size=4, hash_key=None), 'x_bucketized_X_y_bucketized': _CrossedColumn(keys=(_BucketizedColumn(source_column=_NumericColumn(key='x', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None), boundaries=(-3.0, -1.5, 0.0, 1.5, 3.0)), _BucketizedColumn(source_column=_NumericColumn(key='y', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None), boundaries=(-3.0, -1.5, 0.0, 1.5, 3.0))), hash_bucket_size=25, hash_key=None), 'x_bucketized_X_y_bucketized_embedded': _EmbeddingColumn(categorical_column=_CrossedColumn(keys=(_BucketizedColumn(source_column=_NumericColumn(key='x', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None), boundaries=(-3.0, -1.5, 0.0, 1.5, 3.0)), _BucketizedColumn(source_column=_NumericColumn(key='y', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None), boundaries=(-3.0, -1.5, 0.0, 1.5, 3.0))), hash_bucket_size=25, hash_key=None), dimension=3, combiner='mean', initializer=<tensorflow.python.ops.init_ops.TruncatedNormal object at 0x11a51b710>, ckpt_to_load_from=None, tensor_name_in_ckpt=None, max_norm=None, trainable=True)}

# %% [markdown]
# ## 4. Define an Estimator Creation Function

# %% [markdown]
# ### a. Get wide and deep feature columns
# * dense columns = numeric columns + embedding columns
# * categorical columns = vocabolary list columns + bucketized columns
# * sparse columns = hashed categorical columns + crossed columns
# * categorical columns => indicator columns
# * deep columns = dense columns + indicator columns
# * wide columns = categorical columns + sparse columns

# %%
def get_wide_deep_columns():
    
    feature_columns = list(get_feature_columns(hparams).values())
    
    dense_columns = list(
        filter(lambda column: isinstance(column, feature_column._NumericColumn) |
                              isinstance(column, feature_column._EmbeddingColumn),
               feature_columns
        )
    )

    categorical_columns = list(
        filter(lambda column: isinstance(column, feature_column._VocabularyListCategoricalColumn) |
                              isinstance(column, feature_column._BucketizedColumn),
                   feature_columns)
    )
    
    sparse_columns = list(
        filter(lambda column: isinstance(column,feature_column._HashedCategoricalColumn) |
                              isinstance(column, feature_column._CrossedColumn),
               feature_columns)
    )

    indicator_columns = list(
            map(lambda column: tf.feature_column.indicator_column(column),
                categorical_columns)
    )
    
    deep_feature_columns = dense_columns + indicator_columns
    wide_feature_columns = categorical_columns + sparse_columns
    
    return wide_feature_columns, deep_feature_columns

# %%
def create_estimator(run_config, hparams, print_desc=False):
    
    wide_feature_columns, deep_feature_columns = get_wide_deep_columns()
    
    estimator = tf.estimator.DNNLinearCombinedRegressor(
        
        dnn_feature_columns = deep_feature_columns,
        linear_feature_columns = wide_feature_columns,
        
        dnn_hidden_units= hparams.hidden_units,
        
        dnn_optimizer= tf.train.AdamOptimizer(),
        
        dnn_activation_fn= tf.nn.elu,
        dnn_dropout= hparams.dropout_prob,
        
        config= run_config
    )
    
    
    if print_desc:
        print("")
        print("*Estimator Type:")
        print("================")
        print(type(estimator))
        print("")
        print("*deep columns:")
        print("==============")
        print(deep_feature_columns)
        print("")
        print("wide columns:")
        print("=============")
        print(wide_feature_columns)
        print("")
    
    return estimator

# %% [markdown]
# ## 5. Run Experiment

# %% [markdown]
# ### a. Set HParam and RunConfig

# %%
TRAIN_SIZE = 12000
NUM_EPOCHS = 1000
BATCH_SIZE = 500
NUM_EVAL = 10

TOTAL_STEPS = (TRAIN_SIZE/BATCH_SIZE)*NUM_EPOCHS
CHECKPOINT_STEPS = int((TRAIN_SIZE/BATCH_SIZE) * (NUM_EPOCHS/NUM_EVAL))

hparams  = tf.contrib.training.HParams(
    num_epochs = NUM_EPOCHS,
    batch_size = BATCH_SIZE,
    hidden_units=[16, 12, 8],
    num_buckets = 6,
    embedding_size = 3,
    max_steps = TOTAL_STEPS,
    dropout_prob = 0.001)

model_dir = 'trained_models/{}'.format(MODEL_NAME)

run_config = tf.contrib.learn.RunConfig(
    save_checkpoints_steps=CHECKPOINT_STEPS,
    tf_random_seed=19830610,
    model_dir=model_dir
)

print(hparams)
print("Model Directory:", run_config.model_dir)
print("")
print("Dataset Size:", TRAIN_SIZE)
print("Batch Size:", BATCH_SIZE)
print("Steps per Epoch:",TRAIN_SIZE/BATCH_SIZE)
print("Total Steps:", TOTAL_STEPS)
print("Required Evaluation Steps:", NUM_EVAL) 
print("That is 1 evaluation step after each",NUM_EPOCHS/NUM_EVAL," epochs")
print("Save Checkpoint After",CHECKPOINT_STEPS,"steps")
# Out:
# [('batch_size', 500), ('dropout_prob', 0.001), ('embedding_size', 3), ('hidden_units', [16, 12, 8]), ('max_steps', 24000.0), ('num_buckets', 6), ('num_epochs', 1000)]
# Model Directory: trained_models/reg-model-06
#
# Dataset Size: 12000
# Batch Size: 500
# Steps per Epoch: 24.0
# Total Steps: 24000.0
# Required Evaluation Steps: 10
# That is 1 evaluation step after each 100.0  epochs
# Save Checkpoint After 2400 steps

# %% [markdown]
# ###  b. Define Serving Function

# %%
def csv_serving_input_fn():
    
    SERVING_HEADER = ['x','y','alpha','beta']
    SERVING_HEADER_DEFAULTS = [[0.0], [0.0], ['NA'], ['NA']]

    rows_string_tensor = tf.placeholder(dtype=tf.string,
                                         shape=[None],
                                         name='csv_rows')
    
    receiver_tensor = {'csv_rows': rows_string_tensor}

    row_columns = tf.expand_dims(rows_string_tensor, -1)
    columns = tf.decode_csv(row_columns, record_defaults=SERVING_HEADER_DEFAULTS)
    features = dict(zip(SERVING_HEADER, columns))
    
    if PROCESS_FEATURES:
        features = process_features(features)

    return tf.estimator.export.ServingInputReceiver(
        features, receiver_tensor)

# %% [markdown]
# ### c. Define TrainSpec and EvaluSpec

# %%
train_spec = tf.estimator.TrainSpec(
    input_fn = lambda: tfrecods_input_fn(
        TRAIN_DATA_FILES_PATTERN,
        mode = tf.contrib.learn.ModeKeys.TRAIN,
        num_epochs=hparams.num_epochs,
        batch_size=hparams.batch_size
    ),
    max_steps=hparams.max_steps,
    hooks=None
)

eval_spec = tf.estimator.EvalSpec(
    input_fn = lambda: tfrecods_input_fn(
        VALID_DATA_FILES_PATTERN,
        mode=tf.contrib.learn.ModeKeys.EVAL,
        num_epochs=1,
        batch_size=hparams.batch_size
    ),
    exporters=[tf.estimator.LatestExporter(
        name="estimate",  # the name of the folder in which the model will be exported to under export
        serving_input_receiver_fn=csv_serving_input_fn,
        exports_to_keep=1,
        as_text=True)],
    steps=None,
    hooks=None
)

# %% [markdown]
# ### d. Run Experiment via train_and_evaluate

# %%
if not RESUME_TRAINING:
    print("Removing previous artifacts...")
    shutil.rmtree(model_dir, ignore_errors=True)
else:
    print("Resuming training...") 

    
tf.logging.set_verbosity(tf.logging.INFO)

time_start = datetime.utcnow() 
print("Experiment started at {}".format(time_start.strftime("%H:%M:%S")))
print(".......................................") 

estimator = create_estimator(run_config, hparams, True)

tf.estimator.train_and_evaluate(
    estimator=estimator,
    train_spec=train_spec, 
    eval_spec=eval_spec
)

time_end = datetime.utcnow() 
print(".......................................")
print("Experiment finished at {}".format(time_end.strftime("%H:%M:%S")))
print("")
time_elapsed = time_end - time_start
print("Experiment elapsed time: {} seconds".format(time_elapsed.total_seconds()))
# Out:
# Removing previous artifacts...
# Experiment started at 18:17:59
# .......................................
# INFO:tensorflow:Using config: {'_task_type': None, '_task_id': 0, '_cluster_spec': <tensorflow.python.training.server_lib.ClusterSpec object at 0x11a52b208>, '_master': '', '_num_ps_replicas': 0, '_num_worker_replicas': 0, '_environment': 'local', '_is_chief': True, '_evaluation_master': '', '_tf_config': gpu_options {
#   per_process_gpu_memory_fraction: 1
# }
# , '_tf_random_seed': 19830610, '_save_summary_steps': 100, '_save_checkpoints_secs': None, '_log_step_count_steps': 100, '_session_config': None, '_save_checkpoints_steps': 2400, '_keep_checkpoint_max': 5, '_keep_checkpoint_every_n_hours': 10000, '_model_dir': 'trained_models/reg-model-06'}
#
# *Estimator Type:
# ================
# <class 'tensorflow.python.estimator.canned.dnn_linear_combined.DNNLinearCombinedRegressor'>
#
# *deep columns:
# ==============
# [_NumericColumn(key='x', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None), _NumericColumn(key='y', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None), _NumericColumn(key='x_2', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None), _NumericColumn(key='y_2', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None), _NumericColumn(key='xy', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None), _NumericColumn(key='dist_xy', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None), _NumericColumn(key='sin_x', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None), _NumericColumn(key='cos_y', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None), _EmbeddingColumn(categorical_column=_CrossedColumn(keys=(_BucketizedColumn(source_column=_NumericColumn(key='x', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None), boundaries=(-3.0, -1.8, -0.6000000000000001, 0.5999999999999996, 1.7999999999999998, 3.0)), _BucketizedColumn(source_column=_NumericColumn(key='y', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None), boundaries=(-3.0, -1.8, -0.6000000000000001, 0.5999999999999996, 1.7999999999999998, 3.0))), hash_bucket_size=36, hash_key=None), dimension=3, combiner='mean', initializer=<tensorflow.python.ops.init_ops.TruncatedNormal object at 0x11a423be0>, ckpt_to_load_from=None, tensor_name_in_ckpt=None, max_norm=None, trainable=True), _IndicatorColumn(categorical_column=_VocabularyListCategoricalColumn(key='alpha', vocabulary_list=('ax01', 'ax02'), dtype=tf.string, default_value=-1, num_oov_buckets=0)), _IndicatorColumn(categorical_column=_VocabularyListCategoricalColumn(key='beta', vocabulary_list=('bx01', 'bx02'), dtype=tf.string, default_value=-1, num_oov_buckets=0))]
#
# wide columns:
# =============
# [_VocabularyListCategoricalColumn(key='alpha', vocabulary_list=('ax01', 'ax02'), dtype=tf.string, default_value=-1, num_oov_buckets=0), _VocabularyListCategoricalColumn(key='beta', vocabulary_list=('bx01', 'bx02'), dtype=tf.string, default_value=-1, num_oov_buckets=0), _CrossedColumn(keys=(_VocabularyListCategoricalColumn(key='alpha', vocabulary_list=('ax01', 'ax02'), dtype=tf.string, default_value=-1, num_oov_buckets=0), _VocabularyListCategoricalColumn(key='beta', vocabulary_list=('bx01', 'bx02'), dtype=tf.string, default_value=-1, num_oov_buckets=0)), hash_bucket_size=4, hash_key=None), _CrossedColumn(keys=(_BucketizedColumn(source_column=_NumericColumn(key='x', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None), boundaries=(-3.0, -1.8, -0.6000000000000001, 0.5999999999999996, 1.7999999999999998, 3.0)), _BucketizedColumn(source_column=_NumericColumn(key='y', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None), boundaries=(-3.0, -1.8, -0.6000000000000001, 0.5999999999999996, 1.7999999999999998, 3.0))), hash_bucket_size=36, hash_key=None)]
#
# INFO:tensorflow:Running training and evaluation locally (non-distributed).
# INFO:tensorflow:Start train and evaluate loop. The evaluate will happen after 600 secs (eval_spec.throttle_secs) or training is finished.
#
# * data input_fn:
# ================
# Input file(s): data/train-*.tfrecords
# Batch size: 500
# Epoch Count: 1000
# Mode: train
# Shuffle: True
# ================
#
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Saving checkpoints for 1 into trained_models/reg-model-06/model.ckpt.
# INFO:tensorflow:loss = 159622.0, step = 1
# INFO:tensorflow:global_step/sec: 164.808
# INFO:tensorflow:loss = 139077.0, step = 101 (0.608 sec)
# INFO:tensorflow:global_step/sec: 190.924
# INFO:tensorflow:loss = 129130.0, step = 201 (0.530 sec)
# INFO:tensorflow:global_step/sec: 199.805
# INFO:tensorflow:loss = 107341.0, step = 301 (0.494 sec)
# INFO:tensorflow:global_step/sec: 229.475
# INFO:tensorflow:loss = 88040.5, step = 401 (0.435 sec)
# INFO:tensorflow:global_step/sec: 201.203
# INFO:tensorflow:loss = 68818.4, step = 501 (0.498 sec)
# INFO:tensorflow:global_step/sec: 194.476
# INFO:tensorflow:loss = 66175.3, step = 601 (0.515 sec)
# INFO:tensorflow:global_step/sec: 203.928
# INFO:tensorflow:loss = 66000.3, step = 701 (0.490 sec)
# INFO:tensorflow:global_step/sec: 206.332
# INFO:tensorflow:loss = 60487.0, step = 801 (0.485 sec)
# INFO:tensorflow:global_step/sec: 215.093
# INFO:tensorflow:loss = 54708.5, step = 901 (0.465 sec)
# INFO:tensorflow:global_step/sec: 196.811
# INFO:tensorflow:loss = 49084.7, step = 1001 (0.508 sec)
# INFO:tensorflow:global_step/sec: 212.194
# INFO:tensorflow:loss = 56067.9, step = 1101 (0.471 sec)
# INFO:tensorflow:global_step/sec: 193.825
# INFO:tensorflow:loss = 45968.8, step = 1201 (0.516 sec)
# INFO:tensorflow:global_step/sec: 205.015
# INFO:tensorflow:loss = 42409.5, step = 1301 (0.488 sec)
# INFO:tensorflow:global_step/sec: 208.891
# INFO:tensorflow:loss = 45927.4, step = 1401 (0.478 sec)
# INFO:tensorflow:global_step/sec: 251.417
# INFO:tensorflow:loss = 45670.9, step = 1501 (0.398 sec)
# INFO:tensorflow:global_step/sec: 250.198
# INFO:tensorflow:loss = 54748.6, step = 1601 (0.400 sec)
# INFO:tensorflow:global_step/sec: 205.283
# INFO:tensorflow:loss = 39536.5, step = 1701 (0.487 sec)
# INFO:tensorflow:global_step/sec: 205.844
# INFO:tensorflow:loss = 49678.5, step = 1801 (0.487 sec)
# INFO:tensorflow:global_step/sec: 243.329
# INFO:tensorflow:loss = 39058.6, step = 1901 (0.408 sec)
# INFO:tensorflow:global_step/sec: 246.585
# INFO:tensorflow:loss = 52278.8, step = 2001 (0.406 sec)
# INFO:tensorflow:global_step/sec: 232.263
# INFO:tensorflow:loss = 51983.7, step = 2101 (0.431 sec)
# INFO:tensorflow:global_step/sec: 210.408
# INFO:tensorflow:loss = 36337.5, step = 2201 (0.474 sec)
# INFO:tensorflow:global_step/sec: 188.957
# INFO:tensorflow:loss = 44678.9, step = 2301 (0.530 sec)
# INFO:tensorflow:Saving checkpoints for 2401 into trained_models/reg-model-06/model.ckpt.
# INFO:tensorflow:global_step/sec: 57.9215
# INFO:tensorflow:loss = 43197.4, step = 2401 (1.728 sec)
# INFO:tensorflow:global_step/sec: 245.806
# INFO:tensorflow:loss = 44584.6, step = 2501 (0.407 sec)
# INFO:tensorflow:global_step/sec: 190.726
# INFO:tensorflow:loss = 38859.2, step = 2601 (0.523 sec)
# INFO:tensorflow:global_step/sec: 199.053
# INFO:tensorflow:loss = 37233.3, step = 2701 (0.502 sec)
# INFO:tensorflow:global_step/sec: 195.099
# INFO:tensorflow:loss = 45915.3, step = 2801 (0.513 sec)
# INFO:tensorflow:global_step/sec: 194.146
# INFO:tensorflow:loss = 40767.3, step = 2901 (0.515 sec)
# INFO:tensorflow:global_step/sec: 191.439
# INFO:tensorflow:loss = 57571.6, step = 3001 (0.525 sec)
# INFO:tensorflow:global_step/sec: 214.937
# INFO:tensorflow:loss = 45167.2, step = 3101 (0.463 sec)
# INFO:tensorflow:global_step/sec: 237.852
# INFO:tensorflow:loss = 51539.9, step = 3201 (0.421 sec)
# INFO:tensorflow:global_step/sec: 270.443
# INFO:tensorflow:loss = 44491.3, step = 3301 (0.369 sec)
# INFO:tensorflow:global_step/sec: 227.533
# INFO:tensorflow:loss = 45038.3, step = 3401 (0.440 sec)
# INFO:tensorflow:global_step/sec: 212.125
# INFO:tensorflow:loss = 45594.9, step = 3501 (0.471 sec)
# INFO:tensorflow:global_step/sec: 227.701
# INFO:tensorflow:loss = 47900.2, step = 3601 (0.439 sec)
# INFO:tensorflow:global_step/sec: 275.8
# INFO:tensorflow:loss = 40033.9, step = 3701 (0.362 sec)
# INFO:tensorflow:global_step/sec: 275.364
# INFO:tensorflow:loss = 44096.7, step = 3801 (0.363 sec)
# INFO:tensorflow:global_step/sec: 238.823
# INFO:tensorflow:loss = 47743.0, step = 3901 (0.424 sec)
# INFO:tensorflow:global_step/sec: 173.771
# INFO:tensorflow:loss = 43577.4, step = 4001 (0.575 sec)
# INFO:tensorflow:global_step/sec: 188.447
# INFO:tensorflow:loss = 38733.0, step = 4101 (0.533 sec)
# INFO:tensorflow:global_step/sec: 148.145
# INFO:tensorflow:loss = 43942.8, step = 4201 (0.677 sec)
# INFO:tensorflow:global_step/sec: 139.651
# INFO:tensorflow:loss = 35773.6, step = 4301 (0.715 sec)
# INFO:tensorflow:global_step/sec: 142.648
# INFO:tensorflow:loss = 36817.4, step = 4401 (0.698 sec)
# INFO:tensorflow:global_step/sec: 143.205
# INFO:tensorflow:loss = 53457.9, step = 4501 (0.701 sec)
# INFO:tensorflow:global_step/sec: 152.882
# INFO:tensorflow:loss = 38919.9, step = 4601 (0.653 sec)
# INFO:tensorflow:global_step/sec: 146.834
# INFO:tensorflow:loss = 41189.5, step = 4701 (0.680 sec)
# INFO:tensorflow:Saving checkpoints for 4801 into trained_models/reg-model-06/model.ckpt.
# INFO:tensorflow:global_step/sec: 35.4633
# INFO:tensorflow:loss = 38943.7, step = 4801 (2.817 sec)
# INFO:tensorflow:global_step/sec: 174.695
# INFO:tensorflow:loss = 45910.7, step = 4901 (0.576 sec)
# INFO:tensorflow:global_step/sec: 168.72
# INFO:tensorflow:loss = 50691.6, step = 5001 (0.588 sec)
# INFO:tensorflow:global_step/sec: 176.789
# INFO:tensorflow:loss = 43219.7, step = 5101 (0.569 sec)
# INFO:tensorflow:global_step/sec: 191.258
# INFO:tensorflow:loss = 40576.5, step = 5201 (0.520 sec)
# INFO:tensorflow:global_step/sec: 238.274
# INFO:tensorflow:loss = 46685.0, step = 5301 (0.419 sec)
# INFO:tensorflow:global_step/sec: 259.471
# INFO:tensorflow:loss = 48828.9, step = 5401 (0.386 sec)
# INFO:tensorflow:global_step/sec: 244.325
# INFO:tensorflow:loss = 40956.9, step = 5501 (0.408 sec)
# INFO:tensorflow:global_step/sec: 200.05
# INFO:tensorflow:loss = 43771.8, step = 5601 (0.500 sec)
# INFO:tensorflow:global_step/sec: 236.458
# INFO:tensorflow:loss = 37183.6, step = 5701 (0.422 sec)
# INFO:tensorflow:global_step/sec: 240.743
# INFO:tensorflow:loss = 44573.7, step = 5801 (0.416 sec)
# INFO:tensorflow:global_step/sec: 250.926
# INFO:tensorflow:loss = 46787.0, step = 5901 (0.398 sec)
# INFO:tensorflow:global_step/sec: 227.74
# INFO:tensorflow:loss = 45550.3, step = 6001 (0.445 sec)
# INFO:tensorflow:global_step/sec: 233.299
# INFO:tensorflow:loss = 45643.1, step = 6101 (0.422 sec)
# INFO:tensorflow:global_step/sec: 261.609
# INFO:tensorflow:loss = 44608.3, step = 6201 (0.382 sec)
# INFO:tensorflow:global_step/sec: 186.021
# INFO:tensorflow:loss = 50769.0, step = 6301 (0.540 sec)
# INFO:tensorflow:global_step/sec: 201.004
# INFO:tensorflow:loss = 41182.5, step = 6401 (0.498 sec)
# INFO:tensorflow:global_step/sec: 193.208
# INFO:tensorflow:loss = 44410.1, step = 6501 (0.515 sec)
# INFO:tensorflow:global_step/sec: 221.803
# INFO:tensorflow:loss = 34989.5, step = 6601 (0.450 sec)
# INFO:tensorflow:global_step/sec: 243.11
# INFO:tensorflow:loss = 42356.4, step = 6701 (0.411 sec)
# INFO:tensorflow:global_step/sec: 258.229
# INFO:tensorflow:loss = 45027.5, step = 6801 (0.387 sec)
# INFO:tensorflow:global_step/sec: 243.18
# INFO:tensorflow:loss = 45971.1, step = 6901 (0.412 sec)
# INFO:tensorflow:global_step/sec: 256.735
# INFO:tensorflow:loss = 37333.7, step = 7001 (0.389 sec)
# INFO:tensorflow:global_step/sec: 259.989
# INFO:tensorflow:loss = 50497.9, step = 7101 (0.385 sec)
# INFO:tensorflow:Saving checkpoints for 7201 into trained_models/reg-model-06/model.ckpt.
# INFO:tensorflow:global_step/sec: 53.132
# INFO:tensorflow:loss = 53452.2, step = 7201 (1.883 sec)
# INFO:tensorflow:global_step/sec: 176.276
# INFO:tensorflow:loss = 42178.2, step = 7301 (0.573 sec)
# INFO:tensorflow:global_step/sec: 200.801
# INFO:tensorflow:loss = 45283.3, step = 7401 (0.491 sec)
# INFO:tensorflow:global_step/sec: 166.845
# INFO:tensorflow:loss = 54747.9, step = 7501 (0.604 sec)
# INFO:tensorflow:global_step/sec: 190.628
# INFO:tensorflow:loss = 42141.2, step = 7601 (0.522 sec)
# INFO:tensorflow:global_step/sec: 196.958
# INFO:tensorflow:loss = 33489.4, step = 7701 (0.507 sec)
# INFO:tensorflow:global_step/sec: 210.287
# INFO:tensorflow:loss = 54023.6, step = 7801 (0.477 sec)
# INFO:tensorflow:global_step/sec: 164.594
# INFO:tensorflow:loss = 43825.7, step = 7901 (0.609 sec)
# INFO:tensorflow:global_step/sec: 164.996
# INFO:tensorflow:loss = 40400.7, step = 8001 (0.606 sec)
# INFO:tensorflow:global_step/sec: 173.843
# INFO:tensorflow:loss = 34497.2, step = 8101 (0.576 sec)
# INFO:tensorflow:global_step/sec: 162.694
# INFO:tensorflow:loss = 52359.0, step = 8201 (0.613 sec)
# INFO:tensorflow:global_step/sec: 176.113
# INFO:tensorflow:loss = 31653.7, step = 8301 (0.570 sec)
# INFO:tensorflow:global_step/sec: 164.946
# INFO:tensorflow:loss = 48754.1, step = 8401 (0.602 sec)
# INFO:tensorflow:global_step/sec: 192.643
# INFO:tensorflow:loss = 40537.5, step = 8501 (0.520 sec)
# INFO:tensorflow:global_step/sec: 196.491
# INFO:tensorflow:loss = 40405.5, step = 8601 (0.508 sec)
# INFO:tensorflow:global_step/sec: 177.143
# INFO:tensorflow:loss = 37382.7, step = 8701 (0.565 sec)
# INFO:tensorflow:global_step/sec: 221.628
# INFO:tensorflow:loss = 44878.8, step = 8801 (0.450 sec)
# INFO:tensorflow:global_step/sec: 188.454
# INFO:tensorflow:loss = 37740.8, step = 8901 (0.530 sec)
# INFO:tensorflow:global_step/sec: 278.194
# INFO:tensorflow:loss = 38818.1, step = 9001 (0.359 sec)
# INFO:tensorflow:global_step/sec: 268.586
# INFO:tensorflow:loss = 36160.6, step = 9101 (0.372 sec)
# INFO:tensorflow:global_step/sec: 192.514
# INFO:tensorflow:loss = 41361.0, step = 9201 (0.520 sec)
# INFO:tensorflow:global_step/sec: 257.129
# INFO:tensorflow:loss = 45635.6, step = 9301 (0.388 sec)
# INFO:tensorflow:global_step/sec: 241.135
# INFO:tensorflow:loss = 39680.9, step = 9401 (0.415 sec)
# INFO:tensorflow:global_step/sec: 268.788
# INFO:tensorflow:loss = 39602.2, step = 9501 (0.372 sec)
# INFO:tensorflow:Saving checkpoints for 9601 into trained_models/reg-model-06/model.ckpt.
# INFO:tensorflow:global_step/sec: 42.2026
# INFO:tensorflow:loss = 43541.6, step = 9601 (2.372 sec)
# INFO:tensorflow:global_step/sec: 176.241
# INFO:tensorflow:loss = 53467.1, step = 9701 (0.567 sec)
# INFO:tensorflow:global_step/sec: 180.713
# INFO:tensorflow:loss = 37287.1, step = 9801 (0.555 sec)
# INFO:tensorflow:global_step/sec: 167.583
# INFO:tensorflow:loss = 43367.0, step = 9901 (0.595 sec)
# INFO:tensorflow:global_step/sec: 155.161
# INFO:tensorflow:loss = 51177.9, step = 10001 (0.643 sec)
# INFO:tensorflow:global_step/sec: 171.684
# INFO:tensorflow:loss = 55327.3, step = 10101 (0.583 sec)
# INFO:tensorflow:global_step/sec: 163.085
# INFO:tensorflow:loss = 42118.0, step = 10201 (0.613 sec)
# INFO:tensorflow:global_step/sec: 155.426
# INFO:tensorflow:loss = 39559.1, step = 10301 (0.646 sec)
# INFO:tensorflow:global_step/sec: 161.347
# INFO:tensorflow:loss = 38577.9, step = 10401 (0.620 sec)
# INFO:tensorflow:global_step/sec: 173.068
# INFO:tensorflow:loss = 42644.7, step = 10501 (0.575 sec)
# INFO:tensorflow:global_step/sec: 171.658
# INFO:tensorflow:loss = 38155.1, step = 10601 (0.585 sec)
# INFO:tensorflow:global_step/sec: 154.48
# INFO:tensorflow:loss = 44173.0, step = 10701 (0.645 sec)
# INFO:tensorflow:global_step/sec: 165.981
# INFO:tensorflow:loss = 53736.0, step = 10801 (0.602 sec)
# INFO:tensorflow:global_step/sec: 167.641
# INFO:tensorflow:loss = 42220.8, step = 10901 (0.598 sec)
# INFO:tensorflow:global_step/sec: 167.54
# INFO:tensorflow:loss = 45087.8, step = 11001 (0.595 sec)
# INFO:tensorflow:global_step/sec: 160.685
# INFO:tensorflow:loss = 51186.9, step = 11101 (0.624 sec)
# INFO:tensorflow:global_step/sec: 162.772
# INFO:tensorflow:loss = 41878.0, step = 11201 (0.614 sec)
# INFO:tensorflow:global_step/sec: 172.972
# INFO:tensorflow:loss = 50735.0, step = 11301 (0.581 sec)
# INFO:tensorflow:global_step/sec: 173.098
# INFO:tensorflow:loss = 44594.7, step = 11401 (0.575 sec)
# INFO:tensorflow:global_step/sec: 173.086
# INFO:tensorflow:loss = 39645.2, step = 11501 (0.578 sec)
# INFO:tensorflow:global_step/sec: 176.376
# INFO:tensorflow:loss = 39366.8, step = 11601 (0.567 sec)
# INFO:tensorflow:global_step/sec: 157.067
# INFO:tensorflow:loss = 36322.8, step = 11701 (0.636 sec)
# INFO:tensorflow:global_step/sec: 154.94
# INFO:tensorflow:loss = 55460.9, step = 11801 (0.648 sec)
# INFO:tensorflow:global_step/sec: 157.65
# INFO:tensorflow:loss = 48134.1, step = 11901 (0.632 sec)
# INFO:tensorflow:Saving checkpoints for 12001 into trained_models/reg-model-06/model.ckpt.
# INFO:tensorflow:global_step/sec: 40.4837
# INFO:tensorflow:loss = 52856.7, step = 12001 (2.471 sec)
# INFO:tensorflow:global_step/sec: 161.861
# INFO:tensorflow:loss = 41485.0, step = 12101 (0.617 sec)
# INFO:tensorflow:global_step/sec: 168.462
# INFO:tensorflow:loss = 43546.3, step = 12201 (0.591 sec)
# INFO:tensorflow:global_step/sec: 176.813
# INFO:tensorflow:loss = 47113.0, step = 12301 (0.569 sec)
# INFO:tensorflow:global_step/sec: 212.233
# INFO:tensorflow:loss = 41536.5, step = 12401 (0.468 sec)
# INFO:tensorflow:global_step/sec: 205.599
# INFO:tensorflow:loss = 48163.6, step = 12501 (0.487 sec)
# INFO:tensorflow:global_step/sec: 195.5
# INFO:tensorflow:loss = 38975.6, step = 12601 (0.513 sec)
# INFO:tensorflow:global_step/sec: 226.003
# INFO:tensorflow:loss = 47424.4, step = 12701 (0.441 sec)
# INFO:tensorflow:global_step/sec: 198.105
# INFO:tensorflow:loss = 41914.1, step = 12801 (0.504 sec)
# INFO:tensorflow:global_step/sec: 260.159
# INFO:tensorflow:loss = 44889.5, step = 12901 (0.385 sec)
# INFO:tensorflow:global_step/sec: 252.503
# INFO:tensorflow:loss = 44495.1, step = 13001 (0.396 sec)
# INFO:tensorflow:global_step/sec: 236.512
# INFO:tensorflow:loss = 42570.2, step = 13101 (0.423 sec)
# INFO:tensorflow:global_step/sec: 232.918
# INFO:tensorflow:loss = 43013.0, step = 13201 (0.429 sec)
# INFO:tensorflow:global_step/sec: 250.141
# INFO:tensorflow:loss = 37640.5, step = 13301 (0.401 sec)
# INFO:tensorflow:global_step/sec: 239.677
# INFO:tensorflow:loss = 39964.6, step = 13401 (0.416 sec)
# INFO:tensorflow:global_step/sec: 230.068
# INFO:tensorflow:loss = 41560.6, step = 13501 (0.435 sec)
# INFO:tensorflow:global_step/sec: 253.786
# INFO:tensorflow:loss = 39440.7, step = 13601 (0.394 sec)
# INFO:tensorflow:global_step/sec: 251.633
# INFO:tensorflow:loss = 48519.7, step = 13701 (0.398 sec)
# INFO:tensorflow:global_step/sec: 257.9
# INFO:tensorflow:loss = 37971.0, step = 13801 (0.387 sec)
# INFO:tensorflow:global_step/sec: 243.26
# INFO:tensorflow:loss = 45095.1, step = 13901 (0.411 sec)
# INFO:tensorflow:global_step/sec: 241.165
# INFO:tensorflow:loss = 45021.6, step = 14001 (0.414 sec)
# INFO:tensorflow:global_step/sec: 261.995
# INFO:tensorflow:loss = 54590.2, step = 14101 (0.382 sec)
# INFO:tensorflow:global_step/sec: 259.221
# INFO:tensorflow:loss = 36998.4, step = 14201 (0.386 sec)
# INFO:tensorflow:global_step/sec: 243.544
# INFO:tensorflow:loss = 39298.6, step = 14301 (0.410 sec)
# INFO:tensorflow:Saving checkpoints for 14401 into trained_models/reg-model-06/model.ckpt.
# INFO:tensorflow:global_step/sec: 51.2266
# INFO:tensorflow:loss = 48658.0, step = 14401 (1.953 sec)
# INFO:tensorflow:global_step/sec: 232.565
# INFO:tensorflow:loss = 46451.7, step = 14501 (0.430 sec)
# INFO:tensorflow:global_step/sec: 224.507
# INFO:tensorflow:loss = 44237.5, step = 14601 (0.445 sec)
# INFO:tensorflow:global_step/sec: 233.543
# INFO:tensorflow:loss = 39311.8, step = 14701 (0.428 sec)
# INFO:tensorflow:global_step/sec: 234.125
# INFO:tensorflow:loss = 43645.3, step = 14801 (0.428 sec)
# INFO:tensorflow:global_step/sec: 234.764
# INFO:tensorflow:loss = 47568.1, step = 14901 (0.425 sec)
# INFO:tensorflow:global_step/sec: 237.937
# INFO:tensorflow:loss = 50677.8, step = 15001 (0.420 sec)
# INFO:tensorflow:global_step/sec: 239.402
# INFO:tensorflow:loss = 50901.8, step = 15101 (0.418 sec)
# INFO:tensorflow:global_step/sec: 238.917
# INFO:tensorflow:loss = 34974.5, step = 15201 (0.419 sec)
# INFO:tensorflow:global_step/sec: 241.451
# INFO:tensorflow:loss = 51585.9, step = 15301 (0.414 sec)
# INFO:tensorflow:global_step/sec: 243.876
# INFO:tensorflow:loss = 43131.2, step = 15401 (0.410 sec)
# INFO:tensorflow:global_step/sec: 236.586
# INFO:tensorflow:loss = 52182.9, step = 15501 (0.423 sec)
# INFO:tensorflow:global_step/sec: 241.94
# INFO:tensorflow:loss = 43093.3, step = 15601 (0.413 sec)
# INFO:tensorflow:global_step/sec: 232.88
# INFO:tensorflow:loss = 43483.4, step = 15701 (0.429 sec)
# INFO:tensorflow:global_step/sec: 237.849
# INFO:tensorflow:loss = 28363.2, step = 15801 (0.420 sec)
# INFO:tensorflow:global_step/sec: 243.727
# INFO:tensorflow:loss = 29193.1, step = 15901 (0.410 sec)
# INFO:tensorflow:global_step/sec: 224.385
# INFO:tensorflow:loss = 32565.7, step = 16001 (0.446 sec)
# INFO:tensorflow:global_step/sec: 241.628
# INFO:tensorflow:loss = 46874.7, step = 16101 (0.414 sec)
# INFO:tensorflow:global_step/sec: 236.546
# INFO:tensorflow:loss = 42125.5, step = 16201 (0.423 sec)
# INFO:tensorflow:global_step/sec: 236.798
# INFO:tensorflow:loss = 41511.0, step = 16301 (0.422 sec)
# INFO:tensorflow:global_step/sec: 239.878
# INFO:tensorflow:loss = 48414.3, step = 16401 (0.417 sec)
# INFO:tensorflow:global_step/sec: 238.156
# INFO:tensorflow:loss = 40239.2, step = 16501 (0.420 sec)
# INFO:tensorflow:global_step/sec: 241.113
# INFO:tensorflow:loss = 34786.9, step = 16601 (0.414 sec)
# INFO:tensorflow:global_step/sec: 237.61
# INFO:tensorflow:loss = 38471.5, step = 16701 (0.421 sec)
# INFO:tensorflow:Saving checkpoints for 16801 into trained_models/reg-model-06/model.ckpt.
# INFO:tensorflow:global_step/sec: 61.29
# INFO:tensorflow:loss = 50919.4, step = 16801 (1.632 sec)
# INFO:tensorflow:global_step/sec: 235.915
# INFO:tensorflow:loss = 38008.7, step = 16901 (0.423 sec)
# INFO:tensorflow:global_step/sec: 242.713
# INFO:tensorflow:loss = 33534.4, step = 17001 (0.412 sec)
# INFO:tensorflow:global_step/sec: 232.695
# INFO:tensorflow:loss = 45414.6, step = 17101 (0.431 sec)
# INFO:tensorflow:global_step/sec: 235.647
# INFO:tensorflow:loss = 39035.3, step = 17201 (0.423 sec)
# INFO:tensorflow:global_step/sec: 240.426
# INFO:tensorflow:loss = 42127.2, step = 17301 (0.416 sec)
# INFO:tensorflow:global_step/sec: 241.335
# INFO:tensorflow:loss = 48456.1, step = 17401 (0.414 sec)
# INFO:tensorflow:global_step/sec: 241.802
# INFO:tensorflow:loss = 36019.3, step = 17501 (0.414 sec)
# INFO:tensorflow:global_step/sec: 236.387
# INFO:tensorflow:loss = 35454.9, step = 17601 (0.423 sec)
# INFO:tensorflow:global_step/sec: 239.81
# INFO:tensorflow:loss = 37726.3, step = 17701 (0.417 sec)
# INFO:tensorflow:global_step/sec: 238.865
# INFO:tensorflow:loss = 45736.5, step = 17801 (0.418 sec)
# INFO:tensorflow:global_step/sec: 234.9
# INFO:tensorflow:loss = 40299.9, step = 17901 (0.426 sec)
# INFO:tensorflow:global_step/sec: 237.029
# INFO:tensorflow:loss = 48338.2, step = 18001 (0.421 sec)
# INFO:tensorflow:global_step/sec: 240.96
# INFO:tensorflow:loss = 43591.6, step = 18101 (0.415 sec)
# INFO:tensorflow:global_step/sec: 243.278
# INFO:tensorflow:loss = 40333.4, step = 18201 (0.411 sec)
# INFO:tensorflow:global_step/sec: 227.868
# INFO:tensorflow:loss = 39440.7, step = 18301 (0.440 sec)
# INFO:tensorflow:global_step/sec: 238.053
# INFO:tensorflow:loss = 45762.9, step = 18401 (0.420 sec)
# INFO:tensorflow:global_step/sec: 237.245
# INFO:tensorflow:loss = 46763.4, step = 18501 (0.422 sec)
# INFO:tensorflow:global_step/sec: 238.554
# INFO:tensorflow:loss = 46924.9, step = 18601 (0.419 sec)
# INFO:tensorflow:global_step/sec: 237.46
# INFO:tensorflow:loss = 43757.5, step = 18701 (0.421 sec)
# INFO:tensorflow:global_step/sec: 235.576
# INFO:tensorflow:loss = 41785.6, step = 18801 (0.424 sec)
# INFO:tensorflow:global_step/sec: 236.006
# INFO:tensorflow:loss = 45544.8, step = 18901 (0.424 sec)
# INFO:tensorflow:global_step/sec: 240.378
# INFO:tensorflow:loss = 39248.1, step = 19001 (0.416 sec)
# INFO:tensorflow:global_step/sec: 238.826
# INFO:tensorflow:loss = 41600.2, step = 19101 (0.419 sec)
# INFO:tensorflow:Saving checkpoints for 19201 into trained_models/reg-model-06/model.ckpt.
# INFO:tensorflow:global_step/sec: 56.9607
# INFO:tensorflow:loss = 45455.1, step = 19201 (1.756 sec)
# INFO:tensorflow:global_step/sec: 236.825
# INFO:tensorflow:loss = 36862.9, step = 19301 (0.421 sec)
# INFO:tensorflow:global_step/sec: 243.091
# INFO:tensorflow:loss = 33711.6, step = 19401 (0.412 sec)
# INFO:tensorflow:global_step/sec: 237.155
# INFO:tensorflow:loss = 41571.7, step = 19501 (0.422 sec)
# INFO:tensorflow:global_step/sec: 232.345
# INFO:tensorflow:loss = 44965.9, step = 19601 (0.430 sec)
# INFO:tensorflow:global_step/sec: 234.628
# INFO:tensorflow:loss = 43989.7, step = 19701 (0.426 sec)
# INFO:tensorflow:global_step/sec: 235.23
# INFO:tensorflow:loss = 45697.2, step = 19801 (0.425 sec)
# INFO:tensorflow:global_step/sec: 234.865
# INFO:tensorflow:loss = 38425.4, step = 19901 (0.426 sec)
# INFO:tensorflow:global_step/sec: 239.44
# INFO:tensorflow:loss = 46761.3, step = 20001 (0.418 sec)
# INFO:tensorflow:global_step/sec: 236.405
# INFO:tensorflow:loss = 46191.4, step = 20101 (0.423 sec)
# INFO:tensorflow:global_step/sec: 234.056
# INFO:tensorflow:loss = 45463.9, step = 20201 (0.427 sec)
# INFO:tensorflow:global_step/sec: 242.25
# INFO:tensorflow:loss = 43680.9, step = 20301 (0.412 sec)
# INFO:tensorflow:global_step/sec: 240.945
# INFO:tensorflow:loss = 53342.6, step = 20401 (0.422 sec)
# INFO:tensorflow:global_step/sec: 244.66
# INFO:tensorflow:loss = 35989.9, step = 20501 (0.402 sec)
# INFO:tensorflow:global_step/sec: 225.91
# INFO:tensorflow:loss = 41037.9, step = 20601 (0.443 sec)
# INFO:tensorflow:global_step/sec: 243.548
# INFO:tensorflow:loss = 37004.6, step = 20701 (0.411 sec)
# INFO:tensorflow:global_step/sec: 252.279
# INFO:tensorflow:loss = 39274.5, step = 20801 (0.396 sec)
# INFO:tensorflow:global_step/sec: 264.508
# INFO:tensorflow:loss = 54453.7, step = 20901 (0.378 sec)
# INFO:tensorflow:global_step/sec: 267.425
# INFO:tensorflow:loss = 54462.9, step = 21001 (0.374 sec)
# INFO:tensorflow:global_step/sec: 266.216
# INFO:tensorflow:loss = 32152.7, step = 21101 (0.376 sec)
# INFO:tensorflow:global_step/sec: 266.462
# INFO:tensorflow:loss = 33857.5, step = 21201 (0.375 sec)
# INFO:tensorflow:global_step/sec: 268.84
# INFO:tensorflow:loss = 59777.6, step = 21301 (0.372 sec)
# INFO:tensorflow:global_step/sec: 267.778
# INFO:tensorflow:loss = 47467.1, step = 21401 (0.373 sec)
# INFO:tensorflow:global_step/sec: 266.474
# INFO:tensorflow:loss = 38859.1, step = 21501 (0.375 sec)
# INFO:tensorflow:Saving checkpoints for 21601 into trained_models/reg-model-06/model.ckpt.
# INFO:tensorflow:global_step/sec: 58.9019
# INFO:tensorflow:loss = 44337.5, step = 21601 (1.700 sec)
# INFO:tensorflow:global_step/sec: 241.593
# INFO:tensorflow:loss = 46853.2, step = 21701 (0.412 sec)
# INFO:tensorflow:global_step/sec: 240.486
# INFO:tensorflow:loss = 35347.4, step = 21801 (0.416 sec)
# INFO:tensorflow:global_step/sec: 245.733
# INFO:tensorflow:loss = 45101.3, step = 21901 (0.407 sec)
# INFO:tensorflow:global_step/sec: 245.107
# INFO:tensorflow:loss = 39960.3, step = 22001 (0.407 sec)
# INFO:tensorflow:global_step/sec: 246.85
# INFO:tensorflow:loss = 43765.9, step = 22101 (0.405 sec)
# INFO:tensorflow:global_step/sec: 250.408
# INFO:tensorflow:loss = 43033.7, step = 22201 (0.400 sec)
# INFO:tensorflow:global_step/sec: 246.46
# INFO:tensorflow:loss = 49316.0, step = 22301 (0.406 sec)
# INFO:tensorflow:global_step/sec: 243.72
# INFO:tensorflow:loss = 41679.9, step = 22401 (0.410 sec)
# INFO:tensorflow:global_step/sec: 247.599
# INFO:tensorflow:loss = 57324.8, step = 22501 (0.404 sec)
# INFO:tensorflow:global_step/sec: 243.849
# INFO:tensorflow:loss = 45182.3, step = 22601 (0.410 sec)
# INFO:tensorflow:global_step/sec: 245.014
# INFO:tensorflow:loss = 46362.5, step = 22701 (0.408 sec)
# INFO:tensorflow:global_step/sec: 238.061
# INFO:tensorflow:loss = 38099.8, step = 22801 (0.420 sec)
# INFO:tensorflow:global_step/sec: 201.928
# INFO:tensorflow:loss = 37987.9, step = 22901 (0.499 sec)
# INFO:tensorflow:global_step/sec: 222.093
# INFO:tensorflow:loss = 50943.3, step = 23001 (0.447 sec)
# INFO:tensorflow:global_step/sec: 197.865
# INFO:tensorflow:loss = 42481.7, step = 23101 (0.506 sec)
# INFO:tensorflow:global_step/sec: 239.766
# INFO:tensorflow:loss = 47697.2, step = 23201 (0.417 sec)
# INFO:tensorflow:global_step/sec: 244.274
# INFO:tensorflow:loss = 46502.5, step = 23301 (0.409 sec)
# INFO:tensorflow:global_step/sec: 231.485
# INFO:tensorflow:loss = 39387.3, step = 23401 (0.432 sec)
# INFO:tensorflow:global_step/sec: 245.466
# INFO:tensorflow:loss = 33846.2, step = 23501 (0.408 sec)
# INFO:tensorflow:global_step/sec: 240.84
# INFO:tensorflow:loss = 39633.8, step = 23601 (0.415 sec)
# INFO:tensorflow:global_step/sec: 247.095
# INFO:tensorflow:loss = 39092.4, step = 23701 (0.405 sec)
# INFO:tensorflow:global_step/sec: 244.013
# INFO:tensorflow:loss = 49489.9, step = 23801 (0.410 sec)
# INFO:tensorflow:global_step/sec: 241.331
# INFO:tensorflow:loss = 41634.4, step = 23901 (0.414 sec)
# INFO:tensorflow:Saving checkpoints for 24000 into trained_models/reg-model-06/model.ckpt.
# INFO:tensorflow:Loss for final step: 43222.9.
#
# * data input_fn:
# ================
# Input file(s): data/valid-*.tfrecords
# Batch size: 500
# Epoch Count: 1
# Mode: eval
# Shuffle: False
# ================
#
# INFO:tensorflow:Starting evaluation at 2017-11-22-18:20:20
# INFO:tensorflow:Restoring parameters from trained_models/reg-model-06/model.ckpt-24000
# INFO:tensorflow:Finished evaluation at 2017-11-22-18:20:21
# INFO:tensorflow:Saving dict for global step 24000: average_loss = 93.8474, global_step = 24000, loss = 46923.7
# INFO:tensorflow:Restoring parameters from trained_models/reg-model-06/model.ckpt-24000
# INFO:tensorflow:Assets added to graph.
# INFO:tensorflow:No assets to write.
# INFO:tensorflow:SavedModel written to: b"trained_models/reg-model-06/export/estimate/temp-b'1511374823'/saved_model.pbtxt"
# .......................................
# Experiment finished at 18:20:24
#
# Experiment elapsed time: 145.115783 seconds

# %% [markdown]
# ## 6. Evaluate the Model

# %%
TRAIN_SIZE = 12000
VALID_SIZE = 3000
TEST_SIZE = 5000
train_input_fn = lambda: tfrecods_input_fn(files_name_pattern= TRAIN_DATA_FILES_PATTERN, 
                                      mode= tf.estimator.ModeKeys.EVAL,
                                      batch_size= TRAIN_SIZE)

valid_input_fn = lambda: tfrecods_input_fn(files_name_pattern= VALID_DATA_FILES_PATTERN, 
                                      mode= tf.estimator.ModeKeys.EVAL,
                                      batch_size= VALID_SIZE)

test_input_fn = lambda: tfrecods_input_fn(files_name_pattern= TEST_DATA_FILES_PATTERN, 
                                      mode= tf.estimator.ModeKeys.EVAL,
                                      batch_size= TEST_SIZE)

estimator = create_estimator(run_config, hparams)

train_results = estimator.evaluate(input_fn=train_input_fn, steps=1)
train_rmse = round(math.sqrt(train_results["average_loss"]),5)
print()
print("############################################################################################")
print("# Train RMSE: {} - {}".format(train_rmse, train_results))
print("############################################################################################")

valid_results = estimator.evaluate(input_fn=valid_input_fn, steps=1)
valid_rmse = round(math.sqrt(valid_results["average_loss"]),5)
print()
print("############################################################################################")
print("# Valid RMSE: {} - {}".format(valid_rmse,valid_results))
print("############################################################################################")

test_results = estimator.evaluate(input_fn=test_input_fn, steps=1)
test_rmse = round(math.sqrt(test_results["average_loss"]),5)
print()
print("############################################################################################")
print("# Test RMSE: {} - {}".format(test_rmse, test_results))
print("############################################################################################")
# Out:
# INFO:tensorflow:Using config: {'_task_type': None, '_task_id': 0, '_cluster_spec': <tensorflow.python.training.server_lib.ClusterSpec object at 0x11a52b208>, '_master': '', '_num_ps_replicas': 0, '_num_worker_replicas': 0, '_environment': 'local', '_is_chief': True, '_evaluation_master': '', '_tf_config': gpu_options {
#   per_process_gpu_memory_fraction: 1
# }
# , '_tf_random_seed': 19830610, '_save_summary_steps': 100, '_save_checkpoints_secs': None, '_log_step_count_steps': 100, '_session_config': None, '_save_checkpoints_steps': 2400, '_keep_checkpoint_max': 5, '_keep_checkpoint_every_n_hours': 10000, '_model_dir': 'trained_models/reg-model-06'}
#
# * data input_fn:
# ================
# Input file(s): data/train-*.tfrecords
# Batch size: 12000
# Epoch Count: None
# Mode: eval
# Shuffle: False
# ================
#
# INFO:tensorflow:Starting evaluation at 2017-11-22-18:20:26
# INFO:tensorflow:Restoring parameters from trained_models/reg-model-06/model.ckpt-24000
# INFO:tensorflow:Evaluation [1/1]
# INFO:tensorflow:Finished evaluation at 2017-11-22-18:20:26
# INFO:tensorflow:Saving dict for global step 24000: average_loss = 83.5433, global_step = 24000, loss = 1.00252e+06
#
# ############################################################################################
# # Train RMSE: 9.1402 - {'average_loss': 83.543282, 'loss': 1002519.4, 'global_step': 24000}
# ############################################################################################
#
# * data input_fn:
# ================
# Input file(s): data/valid-*.tfrecords
# Batch size: 3000
# Epoch Count: None
# Mode: eval
# Shuffle: False
# ================
#
# INFO:tensorflow:Starting evaluation at 2017-11-22-18:20:27
# INFO:tensorflow:Restoring parameters from trained_models/reg-model-06/model.ckpt-24000
# INFO:tensorflow:Evaluation [1/1]
# INFO:tensorflow:Finished evaluation at 2017-11-22-18:20:28
# INFO:tensorflow:Saving dict for global step 24000: average_loss = 93.8474, global_step = 24000, loss = 281542.0
#
# ############################################################################################
# # Valid RMSE: 9.68749 - {'average_loss': 93.847374, 'loss': 281542.12, 'global_step': 24000}
# ############################################################################################
#
# * data input_fn:
# ================
# Input file(s): data/test-*.tfrecords
# Batch size: 5000
# Epoch Count: None
# Mode: eval
# Shuffle: False
# ================
#
# INFO:tensorflow:Starting evaluation at 2017-11-22-18:20:29
# INFO:tensorflow:Restoring parameters from trained_models/reg-model-06/model.ckpt-24000
# INFO:tensorflow:Evaluation [1/1]
# INFO:tensorflow:Finished evaluation at 2017-11-22-18:20:30
# INFO:tensorflow:Saving dict for global step 24000: average_loss = 94.6189, global_step = 24000, loss = 473095.0
#
# ############################################################################################
# # Test RMSE: 9.72723 - {'average_loss': 94.618927, 'loss': 473094.62, 'global_step': 24000}
# ############################################################################################

# %% [markdown]
# ## 7. Prediction

# %%
import itertools

predict_input_fn = lambda: tfrecods_input_fn(files_name_pattern= TEST_DATA_FILES_PATTERN, 
                                      mode= tf.estimator.ModeKeys.PREDICT,
                                      batch_size= 5)

predictions = estimator.predict(input_fn=predict_input_fn)
values = list(map(lambda item: item["predictions"][0],list(itertools.islice(predictions, 5))))
print()
print("Predicted Values: {}".format(values))
# Out:
# * data input_fn:
# ================
# Input file(s): data/test-*.tfrecords
# Batch size: 5
# Epoch Count: None
# Mode: infer
# Shuffle: False
# ================
#
# WARNING:tensorflow:Input graph does not contain a QueueRunner. That means predict yields forever. This is probably a mistake.
# INFO:tensorflow:Restoring parameters from trained_models/reg-model-06/model.ckpt-24000
#
# Predicted Values: [51.511147, -3.6146288, 17.257666, 2.8943579, 2.9071493]

# %% [markdown]
# ## Serving via the Saved Model

# %%
import os

export_dir = model_dir +"/export/estimate/"

saved_model_dir = export_dir + "/" + os.listdir(path=export_dir)[-1] 

print(saved_model_dir)

predictor_fn = tf.contrib.predictor.from_saved_model(
    export_dir = saved_model_dir,
    signature_def_key="predict"
)

output = predictor_fn({'csv_rows': ["0.5,1,ax01,bx02", "-0.5,-1,ax02,bx02"]})
print(output)
# Out:
# trained_models/reg-model-06/export/estimate//1511374823
# INFO:tensorflow:Restoring parameters from b'trained_models/reg-model-06/export/estimate//1511374823/variables/variables'
# {'predictions': array([[ 62.82740021],
#        [-17.38466835]], dtype=float32)}
